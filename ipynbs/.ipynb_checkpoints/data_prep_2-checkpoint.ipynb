# %% [markdown]
# ## This 2nd data preparation attempt is with the aim to add more features and learn a few data prep tricks from a tutorial

# %% [markdown]
# tutorial = https://www.kaggle.com/c/titanic-gettingStarted/details/getting-started-with-python-ii

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
from itertools import combinations_with_replacement

def polyfeat(df, collist, p=2) :
#     returns df with additional columns df[col1]*df[col2]*..*df[colp] for all
#     col1,col2,...,colp in the collist (with replacement)
    colflag = {col: False for col in collist}
    for col in collist :
        if len(np.unique(df[col].values)) < 3 : #so binary vars don't get
            colflag[col] = True# needlessly multiplied
    for cols in combinations_with_replacement(collist,p) :
        needed = True
        for col in cols :
            if colflag[col] and cols.count(col) > 1 :
                needed = False
        if not needed :
            continue
        name = '*'.join(cols)
        df[name] = 1
        for col in cols : 
            df[name] = df[name] * df[col]

# %%
trainfile = "/Users/dominicspadacene/Desktop/coursera_ml/titanic_challenge/data/train.csv"
outfile = "/Users/dominicspadacene/Desktop/coursera_ml/titanic_challenge/data/train2.csv"
outfile_octave = "/Users/dominicspadacene/Desktop/coursera_ml/titanic_challenge/octave_files/train2.txt"

# %%
df = pd.read_csv(trainfile,index_col='PassengerId')

# %%
df.head(3)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
#
#                                                           Name     Sex  Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male   22
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38
# 3                                       Heikkinen, Miss. Laina  female   26
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
# Survived    891 non-null int64
# Pclass      891 non-null int64
# Name        891 non-null object
# Sex         891 non-null object
# Age         714 non-null float64
# SibSp       891 non-null int64
# Parch       891 non-null int64
# Ticket      891 non-null object
# Fare        891 non-null float64
# Cabin       204 non-null object
# Embarked    889 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %%
df.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.describe(include=['O'])
# Out:
#                              Name   Sex    Ticket        Cabin Embarked
# count                         891   891       891          204      889
# unique                        891     2       681          147        3
# top     Graham, Mr. George Edward  male  CA. 2343  C23 C25 C27        S
# freq                            1   577         7            4      644

# %%
print pd.unique(df.Embarked.values.ravel())

# %timeit pd.unique(df.Embarked.values.ravel())

# %timeit pd.unique(df.Embarked.values)

# %timeit np.unique(df.Embarked.values)
# Out:
# ['S' 'C' 'Q' nan]
# 10000 loops, best of 3: 70 µs per loop
# 10000 loops, best of 3: 69.4 µs per loop
# 10000 loops, best of 3: 53.4 µs per loop

# %%
df.Age.hist(bins=10,range=(0,80),alpha=0.5)#automatically ignores nan
plt.show()

# %% [markdown]
# ### Data cleaning

# %%
df['Gender'] = df.Sex.map({'male': 0,
                            'female' : 1})

# %%
median_ages = np.zeros((2,3))

for i in range(0,2) :
    for j in range(0,3) :
        median_ages[i,j] = df[ (df['Gender'] == i) &
                               (df['Pclass'] == j+1)].Age.dropna().median()

# %%
df['AgeFill'] = df['Age']

# %%
for i in range(0,2):
    for j in range(0,3) :
        df.loc[ (df.Age.isnull()) &
               (df['Pclass'] == j+1) &
               (df['Gender'] == i),
               'AgeFill'] = median_ages[i,j]

# %%
fig,ax = plt.subplots(nrows=1,ncols=2, sharey=True)

df.AgeFill.hist(alpha=0.5,ax=ax[0])
df.Age.hist(alpha=0.5,ax=ax[1])
plt.show()

# %%
df['AgeisNull'] = df.Age.isnull().astype(int)

# %%
df.groupby(by=['Gender','Pclass']).agg(np.median).Age.loc[1,1]
# Out:
# 35.0

# %%
portdf = pd.get_dummies(df.Embarked,prefix='port')
df = pd.merge(df,portdf,left_index=True,right_index=True)

# %% [markdown]
# #### dropping columns not to be used in next ML

# %%
dropcols = ['Sex','Age','Name','Ticket','Cabin','Embarked']
df.drop(dropcols,axis=1,inplace=True)

# %% [markdown]
# ## Feature Engineering

# %%
df['FamilySize'] = df['SibSp'] + df['Parch']

# %%
polycols = ['Pclass','Fare','Gender','AgeFill','FamilySize']
polyfeat(df, polycols, 2)
polyfeat(df, polycols, 3)

# %% [markdown]
# ## Scaling (Same)

# %%
mus = {}
sigs = {}

# %%
for col in df.columns :
    if (min(df[col]) < -3) or (max(df[col]) > 3) :
        mus[col] = df[col].mean()
        sigs[col] = df[col].std()

# %%
for col in mus :
    df[col] = (df[col] - mus[col])/(2 * sigs[col])

# %%
df.head(3)
# Out:
#              Survived  Pclass     SibSp     Parch      Fare  Gender   AgeFill  \
# PassengerId
# 1                   0       3  0.216275 -0.236704 -0.251082       0 -0.267295
# 2                   1       1  0.216275 -0.236704  0.393202       1  0.334008
# 3                   1       3 -0.237139 -0.236704 -0.244290       1 -0.116970
#
#              AgeisNull  port_C  port_Q                ...                 \
# PassengerId                                           ...
# 1                    0       0       0                ...
# 2                    0       1       0                ...
# 3                    0       0       0                ...
#
#              Fare*AgeFill*AgeFill  Fare*AgeFill*FamilySize  \
# PassengerId
# 1                       -0.213670                -0.126383
# 2                        0.389379                 0.177742
# 3                       -0.202459                -0.145412
#
#              Fare*FamilySize*FamilySize  Gender*AgeFill*AgeFill  \
# PassengerId
# 1                             -0.111181               -0.248055
# 2                             -0.071962                0.863318
# 3                             -0.115622                0.272228
#
#              Gender*AgeFill*FamilySize  Gender*FamilySize*FamilySize  \
# PassengerId
# 1                            -0.176913                     -0.111387
# 2                             0.413839                     -0.046605
# 3                            -0.176913                     -0.111387
#
#              AgeFill*AgeFill*AgeFill  AgeFill*AgeFill*FamilySize  \
# PassengerId
# 1                          -0.264583                   -0.059870
# 2                           0.116290                    0.232965
# 3                          -0.204917                   -0.207508
#
#              AgeFill*FamilySize*FamilySize  FamilySize*FamilySize*FamilySize
# PassengerId
# 1                                -0.093288                         -0.093912
# 2                                -0.062755                         -0.093912
# 3                                -0.135270                         -0.099068
#
# [3 rows x 56 columns]

# %% [markdown]
# ## Writing Out

# %%
cols = df.columns.tolist()
cols = cols[1:] + ['Survived']
df = df[cols]
df.head(3)
# Out:
#              Pclass     SibSp     Parch      Fare  Gender   AgeFill  \
# PassengerId
# 1                 3  0.216275 -0.236704 -0.251082       0 -0.267295
# 2                 1  0.216275 -0.236704  0.393202       1  0.334008
# 3                 3 -0.237139 -0.236704 -0.244290       1 -0.116970
#
#              AgeisNull  port_C  port_Q  port_S    ...     \
# PassengerId                                       ...
# 1                    0       0       0       1    ...
# 2                    0       1       0       0    ...
# 3                    0       0       0       1    ...
#
#              Fare*AgeFill*FamilySize  Fare*FamilySize*FamilySize  \
# PassengerId
# 1                          -0.126383                   -0.111181
# 2                           0.177742                   -0.071962
# 3                          -0.145412                   -0.115622
#
#              Gender*AgeFill*AgeFill  Gender*AgeFill*FamilySize  \
# PassengerId
# 1                         -0.248055                  -0.176913
# 2                          0.863318                   0.413839
# 3                          0.272228                  -0.176913
#
#              Gender*FamilySize*FamilySize  AgeFill*AgeFill*AgeFill  \
# PassengerId
# 1                               -0.111387                -0.264583
# 2                               -0.046605                 0.116290
# 3                               -0.111387                -0.204917
#
#              AgeFill*AgeFill*FamilySize  AgeFill*FamilySize*FamilySize  \
# PassengerId
# 1                             -0.059870                      -0.093288
# 2                              0.232965                      -0.062755
# 3                             -0.207508                      -0.135270
#
#              FamilySize*FamilySize*FamilySize  Survived
# PassengerId
# 1                                   -0.093912         0
# 2                                   -0.093912         1
# 3                                   -0.099068         1
#
# [3 rows x 56 columns]

# %%
df.to_csv(outfile, index=False,header=True)
df.to_csv(outfile_octave, index=False,header=False)

# %%
df.iloc[:,26].describe()
# Out:
# count    8.910000e+02
# mean     1.015025e-15
# std      5.000000e-01
# min     -5.660039e-01
# 25%     -2.285595e-01
# 50%     -1.825994e-01
# 75%      4.290103e-02
# max      2.798763e+00
# Name: Pclass*Pclass*Fare, dtype: float64

# %%
df.iloc[0:3,9:]
# Out:
#              port_S  FamilySize  Pclass*Pclass  Pclass*Fare  Pclass*Gender  \
# PassengerId
# 1                 1    0.029563       0.431510     -0.28882              0
# 2                 0    0.029563      -0.730047      0.19136              1
# 3                 1   -0.280330       0.431510     -0.26919              3
#
#              Pclass*AgeFill  Pclass*FamilySize  Fare*Fare  Fare*Gender  \
# PassengerId
# 1                  0.053969           0.089684  -0.099596    -0.193832
# 2                 -0.392431          -0.128347   0.045525     0.687620
# 3                  0.245283          -0.237363  -0.099301    -0.095836
#
#              Fare*AgeFill    ...     Fare*AgeFill*FamilySize  \
# PassengerId                  ...
# 1               -0.234552    ...                   -0.126383
# 2                0.461476    ...                    0.177742
# 3               -0.221843    ...                   -0.145412
#
#              Fare*FamilySize*FamilySize  Gender*AgeFill*AgeFill  \
# PassengerId
# 1                             -0.111181               -0.248055
# 2                             -0.071962                0.863318
# 3                             -0.115622                0.272228
#
#              Gender*AgeFill*FamilySize  Gender*FamilySize*FamilySize  \
# PassengerId
# 1                            -0.176913                     -0.111387
# 2                             0.413839                     -0.046605
# 3                            -0.176913                     -0.111387
#
#              AgeFill*AgeFill*AgeFill  AgeFill*AgeFill*FamilySize  \
# PassengerId
# 1                          -0.264583                   -0.059870
# 2                           0.116290                    0.232965
# 3                          -0.204917                   -0.207508
#
#              AgeFill*FamilySize*FamilySize  FamilySize*FamilySize*FamilySize  \
# PassengerId
# 1                                -0.093288                         -0.093912
# 2                                -0.062755                         -0.093912
# 3                                -0.135270                         -0.099068
#
#              Survived
# PassengerId
# 1                   0
# 2                   1
# 3                   1
#
# [3 rows x 47 columns]

# %%
df.iloc[0,:]
# Out:
# Pclass                              3.000000
# SibSp                               0.216275
# Parch                              -0.236704
# Fare                               -0.251082
# Gender                              0.000000
# AgeFill                            -0.267295
# AgeisNull                           0.000000
# port_C                              0.000000
# port_Q                              0.000000
# port_S                              1.000000
# FamilySize                          0.029563
# Pclass*Pclass                       0.431510
# Pclass*Fare                        -0.288820
# Pclass*Gender                       0.000000
# Pclass*AgeFill                      0.053969
# Pclass*FamilySize                   0.089684
# Fare*Fare                          -0.099596
# Fare*Gender                        -0.193832
# Fare*AgeFill                       -0.234552
# Fare*FamilySize                    -0.147346
# Gender*AgeFill                     -0.316563
# Gender*FamilySize                  -0.193565
# AgeFill*AgeFill                    -0.296388
# AgeFill*FamilySize                  0.014690
# FamilySize*FamilySize              -0.108151
# Pclass*Pclass*Pclass                0.441737
# Pclass*Pclass*Fare                 -0.215255
# Pclass*Pclass*Gender               -0.287161
# Pclass*Pclass*AgeFill               0.188446
# Pclass*Pclass*FamilySize            0.115573
# Pclass*Fare*Fare                   -0.110518
# Pclass*Fare*Gender                 -0.252693
# Pclass*Fare*AgeFill                -0.274143
# Pclass*Fare*FamilySize             -0.133648
# Pclass*Gender*AgeFill              -0.306645
# Pclass*Gender*FamilySize           -0.166039
# Pclass*AgeFill*AgeFill             -0.171046
# Pclass*AgeFill*FamilySize           0.094854
# Pclass*FamilySize*FamilySize       -0.091918
# Fare*Fare*Fare                     -0.053391
# Fare*Fare*Gender                   -0.083586
# Fare*Fare*AgeFill                  -0.093973
# Fare*Fare*FamilySize               -0.087691
# Fare*Gender*AgeFill                -0.172764
# Fare*Gender*FamilySize             -0.122355
# Fare*AgeFill*AgeFill               -0.213670
# Fare*AgeFill*FamilySize            -0.126383
# Fare*FamilySize*FamilySize         -0.111181
# Gender*AgeFill*AgeFill             -0.248055
# Gender*AgeFill*FamilySize          -0.176913
# Gender*FamilySize*FamilySize       -0.111387
# AgeFill*AgeFill*AgeFill            -0.264583
# AgeFill*AgeFill*FamilySize         -0.059870
# AgeFill*FamilySize*FamilySize      -0.093288
# FamilySize*FamilySize*FamilySize   -0.093912
# Survived                            0.000000
# Name: 1, Length: 56, dtype: float64

# %%
theta = """18.42027
  -10.78814
    2.00812
    1.82546
   -8.25568
   -2.71181
  -15.54385
   -0.27770
    1.40161
    1.56330
    0.95482
    2.28445
   -6.33063
   -6.39767
    9.00381
   26.88506
    3.50252
  -18.65666
  -11.35510
   20.45105
   17.55737
   -4.10703
    1.98380
   -0.48835
   -8.32723
    5.43125
   14.03160
    6.23768
  -14.74230
  -11.96613
    5.28346
   -5.04985
    6.34275
   -2.53919
   -7.84598
   -0.84208
   -8.10666
   -5.99514
   -4.77834
  -29.69708
   23.33268
   26.36674
    5.29766
   -4.07650
    3.25126
  -13.89678
   -5.83865
   -4.99015
   -4.67083
    2.77229
    4.99535
    9.74895
    4.56762
    3.50284
    4.73008
   14.52875""".split()

theta = map(float,theta)

# %%
features = ['intercept'] + df.columns.tolist()[:-1]

# %%
theta = zip(features, theta)

# %%
for col,val in theta :
    if abs(val) > 15 :
        print "{:<40} {:<20}".format(col,val)
# Out:
# intercept                                18.42027
# AgeFill                                  -15.54385
# Pclass*AgeFill                           26.88506
# Fare*Fare                                -18.65666
# Fare*AgeFill                             20.45105
# Fare*FamilySize                          17.55737
# Pclass*FamilySize*FamilySize             -29.69708
# Fare*Fare*Fare                           23.33268
# Fare*Fare*Gender                         26.36674
